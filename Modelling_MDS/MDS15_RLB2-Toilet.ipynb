# %% [markdown]
# # Regresi Linear

# %%
# Libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
# Data Preparation
df = pd.read_excel("../Data Final/Final_PM15-Toilet.xlsx")
df = df[df['MDS'] >= 100]

# Cleaning
df['MDWT'] = pd.to_numeric(df['MDWT'], errors='coerce')
df = df.dropna()

# Cleaning - GSM
df['GSM'] = df['GSM'].astype(str)
df = df[df['GSM'].str.len() <= 4].copy()
df['GSM'] = df['GSM'].str.replace(',', '.')
df['GSM'] = df['GSM'].astype(float)

# Create Pseudo_Mass Feature
df['pseudo_mass'] = (df['Mean_Stock Flow'] * df['Mean_Stock Consistency'])/ df['Mean_Yankee Speed']

# Create Coating-Release Ratio Feature
df['coating_release_ratio'] = df['Mean_Flow Coating'] / df['Mean_Flow Release']

# X Variables
features = [
    'Mean_Creping'
]
X = df[features]


# Y Variables
target = 'MDS'
y = df[target]

# %%
y.mean()
# Out:
# np.float64(278.0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 735 to 735
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Start_Time                      1 non-null      datetime64[us]
#  1   End_Time                        1 non-null      datetime64[us]
#  2   Data_Count                      1 non-null      int64
#  3   Mean_Creping                    1 non-null      float64
#  4   Mean_Yankee Speed               1 non-null      float64
#  5   Mean_Pope Reel Speed            1 non-null      float64
#  6   Mean_Yankee Pressure            1 non-null      float64
#  7   Mean_Stock Flow                 1 non-null      float64
#  8   Mean_Stock Consistency          1 non-null      float64
#  9   Mean_Flow Coating               1 non-null      float64
#  10  Mean_Flow Release               1 non-null      float64
#  11  Mean_Jet Wire Ratio             1 non-null      float64
#  12  Mean_Load KWH Tickling Refiner  1 non-null      float64
#  13  Mean_Coating/(Area.Min)         1 non-null      float64
#  14  Join_Key_Timestamp              1 non-null      datetime64[us]
#  15  Date                            1 non-null      datetime64[us]
#  16  Time                            1 non-null      str
#  17  Shift                           1 non-null      int64
#  18  Timestamp                       1 non-null      datetime64[us]
#  19  Grade                           1 non-null      str
#  20  Reel                            1 non-null      object
#  21  Bw                              1 non-null      float64
#  22  Thickness                       1 non-null      float64
#  23  MDT                             1 non-null      int64
#  24  CDT                             1 non-null      int64
#  25  MDWT                            1 non-null      int64
#  26  RATIO MDWT (MDWT/MDT)           1 non-null      float64
#  27  MDS                             1 non-null      int64
#  28  Brightness                      1 non-null      float64
#  29  Insp. Status                    1 non-null      str
#  30  GSM                             1 non-null      float64
#  31  Total NBKP                      1 non-null      float64
#  32  Total LBKP                      1 non-null      int64
#  33  Total BB Recycle                1 non-null      float64
#  34  Sub Total Pulp+Broke            1 non-null      float64
#  35  % NBKP                          1 non-null      float64
#  36  % LBKP                          1 non-null      int64
#  37  % BB Recycle                    1 non-null      float64
#  38  % Pulp+Broke                    1 non-null      float64
#  39  pseudo_mass                     1 non-null      float64
#  40  coating_release_ratio           1 non-null      float64
# dtypes: datetime64[us](5), float64(24), int64(8), object(1), str(3)
# memory usage: 495.0+ bytes

# %%
# Model Regresi Linear
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Model Regresi Linear
#       2 model = sm.OLS(y, X).fit()
# ----> 3 print(model.summary())
#
# File e:\Kuliah\Sun Paper Source\Y Prediction\.venv\Lib\site-packages\statsmodels\regression\linear_model.py:2742, in RegressionResults.summary(self, yname, xname, title, alpha, slim)
#    2739 alpha = float_like(alpha, "alpha", optional=False)
#    2740 slim = bool_like(slim, "slim", optional=False, strict=True)
# -> 2742 jb, jbpv, skew, kurtosis = jarque_bera(self.wresid)
#    2743 omni, omnipv = omni_normtest(self.wresid)
#    2745 eigvals = self.eigenvals
#
# File e:\Kuliah\Sun Paper Source\Y Prediction\.venv\Lib\site-packages\statsmodels\stats\stattools.py:123, in jarque_bera(resids, axis)
#     121 resids = np.atleast_1d(np.asarray(resids, dtype=float))
#     122 if resids.size < 2:
# --> 123     raise ValueError("resids must contain at least 2 elements")
#     124 # Calculate residual skewness and kurtosis
#     125 skew = stats.skew(resids, axis=axis)
#
# ValueError: resids must contain at least 2 elements

# %%
# --- OPSI 1: Model Tanpa Intercept (Sesuai kode awal Anda) ---
model_no_const = sm.OLS(y, X).fit()
y_pred_no = model_no_const.predict(X)

mape_no = np.mean(np.abs((y - y_pred_no) / y)) * 100
r2_no = model_no_const.rsquared  # Mengambil R-sq uncentered

print("--- Model Tanpa Intercept ---")
print(f"R-squared: {r2_no:.4f}")
print(f"MAPE: {mape_no:.2f}%")

# --- OPSI 2: Model Dengan Intercept (Disarankan untuk validasi) ---
X_with_const = sm.add_constant(X)
model_with_const = sm.OLS(y, X_with_const).fit()
y_pred_with = model_with_const.predict(X_with_const)

mape_with = np.mean(np.abs((y - y_pred_with) / y)) * 100
r2_with = model_with_const.rsquared # Mengambil R-sq standar

print("\n--- Model Dengan Intercept ---")
print(f"R-squared: {r2_with:.4f}")
print(f"MAPE: {mape_with:.2f}%")
# Out:
# --- Model Tanpa Intercept ---
# R-squared: 0.9927
# MAPE: 6.67%
#
# --- Model Dengan Intercept ---
# R-squared: 0.5352
# MAPE: 6.67%

# %%
import matplotlib.pyplot as plt
import numpy as np
# Generate a random dataset
data = y
# Create a histogram with 30 bins, blue color, and black edges
plt.hist(data, bins=30, color='blue', edgecolor='black')
# Add labels and title
plt.xlabel('Data Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
# Display the plot
plt.show()

y.max()
# Out:
# np.int64(40)

# %%
print(model_with_const.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MDS   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     199.2
# Date:                Wed, 20 May 2026   Prob (F-statistic):           1.37e-30
# Time:                        10:26:37   Log-Likelihood:                -399.63
# No. Observations:                 175   AIC:                             803.3
# Df Residuals:                     173   BIC:                             809.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1877      1.954      0.096      0.924      -3.669       4.044
# Mean_Creping     1.1871      0.084     14.113      0.000       1.021       1.353
# ==============================================================================
# Omnibus:                        3.795   Durbin-Watson:                   1.152
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.445
# Skew:                          -0.084   Prob(JB):                        0.108
# Kurtosis:                       3.762   Cond. No.                         252.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(model_no_const.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    MDS   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.993
# Method:                 Least Squares   F-statistic:                          2.379e+04
# Date:                Wed, 20 May 2026   Prob (F-statistic):                   4.84e-188
# Time:                        10:26:37   Log-Likelihood:                         -399.63
# No. Observations:                 175   AIC:                                      801.3
# Df Residuals:                     174   BIC:                                      804.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mean_Creping     1.1952      0.008    154.247      0.000       1.180       1.210
# ==============================================================================
# Omnibus:                        3.944   Durbin-Watson:                   1.153
# Prob(Omnibus):                  0.139   Jarque-Bera (JB):                4.645
# Skew:                          -0.098   Prob(JB):                       0.0980
# Kurtosis:                       3.774   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Pemeriksaan Asumsi IIDN

# %% [markdown]
# ### Independen (Autokorelasi)

# %%
DW = sm.stats.durbin_watson(model.resid)
print('Nilai DW =', DW)
if DW > 1.5 and DW < 2.5:
    print('Tidak ada autokorelasi (baik positif maupun negatif)')
elif DW < 1.5:
    print('Terdapat autokorelasi positif.')
elif DW > 2.5:
    print('Terdapat autokorelasi negatif.')
# Out:
# Nilai DW = 1.1533165429685877
# Terdapat autokorelasi positif.

# %% [markdown]
# ### Indentik (Heterokesdastisitas)

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

# Breusch-Pagan Test
# H0: Homoskedastisitas (Varians konstan)
bp_test = het_breuschpagan(model.resid, model.model.exog)
labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
print(dict(zip(labels, bp_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 5
#       1 from statsmodels.stats.diagnostic import het_breuschpagan
#       2
#       3 # Breusch-Pagan Test
#       4 # H0: Homoskedastisitas (Varians konstan)
# ----> 5 bp_test = het_breuschpagan(model.resid, model.model.exog)
#       6 labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
#       7 print(dict(zip(labels, bp_test)))
#
# File e:\Kuliah\Sun Paper Source\Y Prediction\.venv\Lib\site-packages\statsmodels\stats\diagnostic.py:801, in het_breuschpagan(resid, exog_het, robust)
#     733 r"""
#     734 Breusch-Pagan Lagrange Multiplier test for heteroscedasticity
#     735
#    (...)    798    heteroskedasticity". Journal of Econometrics 17 (1): 107–112.
#     799 """
#     800 x = array_like(exog_het, "exog_het", ndim=2)
# --> 801 _check_het_test(x, "The Breusch-Pagan")
#     802 y = array_like(resid, "resid", ndim=1) ** 2
#     803 if not robust:
#
# File e:\Kuliah\Sun Paper Source\Y Prediction\.venv\Lib\site-packages\statsmodels\stats\diagnostic.py:726, in _check_het_test(x, test_name)
#     721 x_max = x.max(axis=0)
#     722 if (
#     723     not np.any(((x_max - x.min(axis=0)) == 0) & (x_max != 0))
#     724     or x.shape[1] < 2
#     725 ):
# --> 726     raise ValueError(
#     727         f"{test_name} test requires exog to have at least "
#     728         "two columns where one is a constant."
#     729     )
#
# ValueError: The Breusch-Pagan test requires exog to have at least two columns where one is a constant.

# %% [markdown]
# Terjadi Heteroskedastisitas yang parah pada model. Varians dari residual terbukti secara empiris tidak konstan.

# %% [markdown]
# ### Normalitas

# %%
# Libraries
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram
plt.figure()
plt.hist(model.resid, bins=30)
plt.title("Histogram Residual")
plt.show()

# %%
# Visualisasi (Q-Q Plot)
sm.qqplot(model.resid, line='45', fit=True)
plt.title("Q-Q Plot Residual")
plt.show()

# %%
# Uji Statistik (Shapiro-Wilk)
# H0: Data berdistribusi normal
# H1: Data tidak berdistribusi normal

stat, p_value = stats.shapiro(model.resid)

# Jika p-value < 0.05, residual tidak berdistribusi normal
print(f"Shapiro-Wilk Test: p-value = {p_value}")
if p_value < 0.05:
    print('residual tidak berdistribusi normal')
else:
    print('residual berdistribusi normal.')
# Out:
# Shapiro-Wilk Test: p-value = 0.04404902203171129
# residual tidak berdistribusi normal

# %% [markdown]
# ### Multikolinearitas

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Menghitung VIF untuk setiap variabel independen
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

print(vif_data)
# Out:
#         Feature         VIF
# 0         const  692.879392
# 1  Mean_Creping    1.000000
